# %%
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %matplotlib inline

# %% [markdown]
# # Visualise ellipsis outputs

# %%
# !ls *.ppm0
# Out:
# ConvMH_MbPlt.00001.ppm0  ConvMH_MbPlt.00012.ppm0  ConvMH_MbPlt.00023.ppm0
# ConvMH_MbPlt.00002.ppm0  ConvMH_MbPlt.00013.ppm0  ConvMH_MbPlt.00024.ppm0
# ConvMH_MbPlt.00003.ppm0  ConvMH_MbPlt.00014.ppm0  ConvMH_MbPlt.00025.ppm0
# ConvMH_MbPlt.00004.ppm0  ConvMH_MbPlt.00015.ppm0  ConvMH_MbPlt.00026.ppm0
# ConvMH_MbPlt.00005.ppm0  ConvMH_MbPlt.00016.ppm0  ConvMH_MbPlt.00027.ppm0
# ConvMH_MbPlt.00006.ppm0  ConvMH_MbPlt.00017.ppm0  ConvMH_MbPlt.00028.ppm0
# ConvMH_MbPlt.00007.ppm0  ConvMH_MbPlt.00018.ppm0  ConvMH_MbPlt.00029.ppm0
# ConvMH_MbPlt.00008.ppm0  ConvMH_MbPlt.00019.ppm0  ConvMH_MbPlt.00030.ppm0
# ConvMH_MbPlt.00009.ppm0  ConvMH_MbPlt.00020.ppm0  ConvMH_MbPlt.00031.ppm0
# ConvMH_MbPlt.00010.ppm0  ConvMH_MbPlt.00021.ppm0  ConvMH_MbPlt.00032.ppm0
# ConvMH_MbPlt.00011.ppm0  ConvMH_MbPlt.00022.ppm0  ConvMH_MbPlt.start.ppm0

# %% [markdown]
# ## Single time step

# %%
def show_PPM(ppmfile,length=18,width=5):
    '''
    Based on a specify output PPM file renders the corresponding image in the notebook
    '''
    fig, ax = plt.subplots(figsize=(length, width))
    ellipsisPPM = Image.open(ppmfile, 'r')
    ax.imshow(np.asarray(ellipsisPPM), interpolation='nearest')
    plt.tight_layout()
    
    return

# %%
show_PPM('ConvMH_MbPlt.00024.ppm0',18,5)

# %% [markdown]
# ### Animation
#
# Convert series of PPM files into an animated gif.
#
# -delay and -quality flags are optional.
# + If -delay is set >4, it will add extra frames to make the movie run more slowly, thereby increasing the size of the file.
# + The default quality is 75 and maximum is 100.

# %%
# !convert -delay 5 -quality 75 ConvMod2.*.ppm0 convection.gif

# %% [markdown]
# ### Visualise the gif in the notebook
#
# ![ellipsis convection model](convection.gif "Convection Model Animation")
