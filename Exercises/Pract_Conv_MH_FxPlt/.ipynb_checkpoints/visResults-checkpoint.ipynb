# %%
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# # Visualise ellipsis outputs

# %%
# !ls *.ppm0
# Out:
# ConvMod2.00001.ppm0  ConvMod2.00062.ppm0  ConvMod2.00123.ppm0
# ConvMod2.00002.ppm0  ConvMod2.00063.ppm0  ConvMod2.00124.ppm0
# ConvMod2.00003.ppm0  ConvMod2.00064.ppm0  ConvMod2.00125.ppm0
# ConvMod2.00004.ppm0  ConvMod2.00065.ppm0  ConvMod2.00126.ppm0
# ConvMod2.00005.ppm0  ConvMod2.00066.ppm0  ConvMod2.00127.ppm0
# ConvMod2.00006.ppm0  ConvMod2.00067.ppm0  ConvMod2.00128.ppm0
# ConvMod2.00007.ppm0  ConvMod2.00068.ppm0  ConvMod2.00129.ppm0
# ConvMod2.00008.ppm0  ConvMod2.00069.ppm0  ConvMod2.00130.ppm0
# ConvMod2.00009.ppm0  ConvMod2.00070.ppm0  ConvMod2.00131.ppm0
# ConvMod2.00010.ppm0  ConvMod2.00071.ppm0  ConvMod2.00132.ppm0
# ConvMod2.00011.ppm0  ConvMod2.00072.ppm0  ConvMod2.00133.ppm0
# ConvMod2.00012.ppm0  ConvMod2.00073.ppm0  ConvMod2.00134.ppm0
# ConvMod2.00013.ppm0  ConvMod2.00074.ppm0  ConvMod2.00135.ppm0
# ConvMod2.00014.ppm0  ConvMod2.00075.ppm0  ConvMod2.00136.ppm0
# ConvMod2.00015.ppm0  ConvMod2.00076.ppm0  ConvMod2.00137.ppm0
# ConvMod2.00016.ppm0  ConvMod2.00077.ppm0  ConvMod2.00138.ppm0
# ConvMod2.00017.ppm0  ConvMod2.00078.ppm0  ConvMod2.00139.ppm0
# ConvMod2.00018.ppm0  ConvMod2.00079.ppm0  ConvMod2.00140.ppm0
# ConvMod2.00019.ppm0  ConvMod2.00080.ppm0  ConvMod2.00141.ppm0
# ConvMod2.00020.ppm0  ConvMod2.00081.ppm0  ConvMod2.00142.ppm0
# ConvMod2.00021.ppm0  ConvMod2.00082.ppm0  ConvMod2.00143.ppm0
# ConvMod2.00022.ppm0  ConvMod2.00083.ppm0  ConvMod2.00144.ppm0
# ConvMod2.00023.ppm0  ConvMod2.00084.ppm0  ConvMod2.00145.ppm0
# ConvMod2.00024.ppm0  ConvMod2.00085.ppm0  ConvMod2.00146.ppm0
# ConvMod2.00025.ppm0  ConvMod2.00086.ppm0  ConvMod2.00147.ppm0
# ConvMod2.00026.ppm0  ConvMod2.00087.ppm0  ConvMod2.00148.ppm0
# ConvMod2.00027.ppm0  ConvMod2.00088.ppm0  ConvMod2.00149.ppm0
# ConvMod2.00028.ppm0  ConvMod2.00089.ppm0  ConvMod2.00150.ppm0
# ConvMod2.00029.ppm0  ConvMod2.00090.ppm0  ConvMod2.00151.ppm0
# ConvMod2.00030.ppm0  ConvMod2.00091.ppm0  ConvMod2.00152.ppm0
# ConvMod2.00031.ppm0  ConvMod2.00092.ppm0  ConvMod2.00153.ppm0
# ConvMod2.00032.ppm0  ConvMod2.00093.ppm0  ConvMod2.00154.ppm0
# ConvMod2.00033.ppm0  ConvMod2.00094.ppm0  ConvMod2.00155.ppm0
# ConvMod2.00034.ppm0  ConvMod2.00095.ppm0  ConvMod2.00156.ppm0
# ConvMod2.00035.ppm0  ConvMod2.00096.ppm0  ConvMod2.00157.ppm0
# ConvMod2.00036.ppm0  ConvMod2.00097.ppm0  ConvMod2.00158.ppm0
# ConvMod2.00037.ppm0  ConvMod2.00098.ppm0  ConvMod2.00159.ppm0
# ConvMod2.00038.ppm0  ConvMod2.00099.ppm0  ConvMod2.00160.ppm0
# ConvMod2.00039.ppm0  ConvMod2.00100.ppm0  ConvMod2.00161.ppm0
# ConvMod2.00040.ppm0  ConvMod2.00101.ppm0  ConvMod2.00162.ppm0
# ConvMod2.00041.ppm0  ConvMod2.00102.ppm0  ConvMod2.00163.ppm0
# ConvMod2.00042.ppm0  ConvMod2.00103.ppm0  ConvMod2.00164.ppm0
# ConvMod2.00043.ppm0  ConvMod2.00104.ppm0  ConvMod2.00165.ppm0
# ConvMod2.00044.ppm0  ConvMod2.00105.ppm0  ConvMod2.00166.ppm0
# ConvMod2.00045.ppm0  ConvMod2.00106.ppm0  ConvMod2.00167.ppm0
# ConvMod2.00046.ppm0  ConvMod2.00107.ppm0  ConvMod2.00168.ppm0
# ConvMod2.00047.ppm0  ConvMod2.00108.ppm0  ConvMod2.00169.ppm0
# ConvMod2.00048.ppm0  ConvMod2.00109.ppm0  ConvMod2.00170.ppm0
# ConvMod2.00049.ppm0  ConvMod2.00110.ppm0  ConvMod2.00171.ppm0
# ConvMod2.00050.ppm0  ConvMod2.00111.ppm0  ConvMod2.00172.ppm0
# ConvMod2.00051.ppm0  ConvMod2.00112.ppm0  ConvMod2.00173.ppm0
# ConvMod2.00052.ppm0  ConvMod2.00113.ppm0  ConvMod2.00174.ppm0
# ConvMod2.00053.ppm0  ConvMod2.00114.ppm0  ConvMod2.00175.ppm0
# ConvMod2.00054.ppm0  ConvMod2.00115.ppm0  ConvMod2.00176.ppm0
# ConvMod2.00055.ppm0  ConvMod2.00116.ppm0  ConvMod2.00177.ppm0
# ConvMod2.00056.ppm0  ConvMod2.00117.ppm0  ConvMod2.00178.ppm0
# ConvMod2.00057.ppm0  ConvMod2.00118.ppm0  ConvMod2.00179.ppm0
# ConvMod2.00058.ppm0  ConvMod2.00119.ppm0  ConvMod2.00180.ppm0
# ConvMod2.00059.ppm0  ConvMod2.00120.ppm0  ConvMod2.start.ppm0
# ConvMod2.00060.ppm0  ConvMod2.00121.ppm0
# ConvMod2.00061.ppm0  ConvMod2.00122.ppm0

# %% [markdown]
# ## Single time step

# %%
def show_PPM(ppmfile,length=18,width=5):
    '''
    Based on a specify output PPM file renders the corresponding image in the notebook
    '''
    fig, ax = plt.subplots(figsize=(length, width))
    ellipsisPPM = Image.open(ppmfile, 'r')
    ax.imshow(np.asarray(ellipsisPPM), interpolation='nearest')
    plt.tight_layout()
    
    return

# %%
show_PPM('ConvMH_FxPlt.00400.ppm0',18,5)

# %% [markdown]
# ### Animation
#
# Convert series of PPM files into an animated gif.
#
# -delay and -quality flags are optional.
# + If -delay is set >4, it will add extra frames to make the movie run more slowly, thereby increasing the size of the file.
# + The default quality is 75 and maximum is 100.

# %%
# !convert -delay 5 -quality 75 ConvMH_FxPlt.*.ppm0 convection.gif

# %% [markdown]
# ### Visualise the gif in the notebook
#
# ![ellipsis convection model](convection.gif "Convection Model Animation")
